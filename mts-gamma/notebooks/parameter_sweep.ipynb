# %%
import numpy as np
from mtsgamma import parameter_sweep

coords = np.random.rand(200, 2) * 508
parameter_sweep(coords, [0.12, 0.16, 0.18], [1.2, 1.6], [300, 450], [0.8, 1.2], 'sweep_results.csv')
print('Saved sweep_results.csv')
